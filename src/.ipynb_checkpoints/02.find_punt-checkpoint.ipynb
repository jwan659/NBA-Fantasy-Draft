# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Read in 2021 player data (per game stats)

# %%
df = pd.read_csv('Data/2021-Player-Data.csv')
df.head(10)
# Out:
#    Rk                              Player Pos   Age   Tm     G    GS    MP  \
# 0   1          Precious Achiuwa\achiupr01  PF  21.0  MIA  61.0   4.0  12.1
# 1   2              Jaylen Adams\adamsja01  PG  24.0  MIL   7.0   0.0   2.6
# 2   3              Steven Adams\adamsst01   C  27.0  NOP  58.0  58.0  27.7
# 3   4               Bam Adebayo\adebaba01   C  23.0  MIA  64.0  64.0  33.5
# 4   5         LaMarcus Aldridge\aldrila01   C  35.0  TOT  26.0  23.0  25.9
# 5   6         Ty-Shon Alexander\alexaty01  SG  22.0  PHO  15.0   0.0   3.1
# 6   7  Nickeil Alexander-Walker\alexani01  SG  22.0  NOP  46.0  13.0  21.9
# 7   8             Grayson Allen\allengr01  SG  25.0  MEM  50.0  38.0  25.2
# 8   9             Jarrett Allen\allenja01   C  22.0  TOT  63.0  45.0  29.6
# 9  10           Al-Farouq Aminu\aminual01  PF  30.0  TOT  23.0  14.0  18.9
#
#     FG   FGA  ...    FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  2.0   3.7  ...  0.509  1.2  2.2   3.4  0.5  0.3  0.5  0.7  1.5   5.0
# 1  0.1   1.1  ...    NaN  0.0  0.4   0.4  0.3  0.0  0.0  0.0  0.1   0.3
# 2  3.3   5.3  ...  0.444  3.7  5.2   8.9  1.9  0.9  0.7  1.3  1.9   7.6
# 3  7.1  12.5  ...  0.799  2.2  6.7   9.0  5.4  1.2  1.0  2.6  2.3  18.7
# 4  5.4  11.4  ...  0.872  0.7  3.8   4.5  1.9  0.4  1.1  1.0  1.8  13.5
# 5  0.2   0.8  ...  0.500  0.1  0.5   0.7  0.4  0.0  0.1  0.2  0.1   0.6
# 6  4.2  10.0  ...  0.727  0.3  2.8   3.1  2.2  1.0  0.5  1.5  1.9  11.0
# 7  3.5   8.3  ...  0.868  0.4  2.8   3.2  2.2  0.9  0.2  1.0  1.4  10.6
# 8  4.7   7.7  ...  0.703  3.1  6.9  10.0  1.7  0.5  1.4  1.6  1.5  12.8
# 9  1.7   4.3  ...  0.818  1.0  3.8   4.8  1.3  0.8  0.4  1.2  1.3   4.4
#
# [10 rows x 30 columns]

# %% [markdown]
# Since we're looking at which stats are most tightly correlated, let's filter out those stats specifically

# %%
corr_columns = ['FG%','FT%','3P','PTS','TRB','AST','STL','BLK','TOV']
corr_df = df[corr_columns]
corr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 712 entries, 0 to 711
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FG%     539 non-null    float64
#  1   FT%     522 non-null    float64
#  2   3P      540 non-null    float64
#  3   PTS     540 non-null    float64
#  4   TRB     540 non-null    float64
#  5   AST     540 non-null    float64
#  6   STL     540 non-null    float64
#  7   BLK     540 non-null    float64
#  8   TOV     540 non-null    float64
# dtypes: float64(9)
# memory usage: 50.2 KB

# %% [markdown]
# Fill in missing values

# %%
corr_df = corr_df.fillna(0)

# %% [markdown]
# Plot histograms for each stat

# %%
fig, axs = plt.subplots(3,3,figsize=(15,15))
corr_df['FG%'].plot(kind='hist', ax=axs[0,0])
corr_df['FT%'].plot(kind='hist', ax=axs[0,1])
corr_df['3P'].plot(kind='hist', ax=axs[0,2])
corr_df['PTS'].plot(kind='hist', ax=axs[1,0])
corr_df['TRB'].plot(kind='hist', ax=axs[1,1])
corr_df['AST'].plot(kind='hist', ax=axs[1,2])
corr_df['STL'].plot(kind='hist', ax=axs[2,0])
corr_df['BLK'].plot(kind='hist', ax=axs[2,1])
corr_df['TOV'].plot(kind='hist', ax=axs[2,2])
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns_plot = sns.heatmap(corr_df.corr(), annot=True, cmap='coolwarm', fmt='.2g', ax=ax)
fig = sns_plot.get_figure()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
calc_vif(corr_df)
# Out:
#   variables        VIF
# 0       FG%  13.154546
# 1       FT%  12.524651
# 2        3P   6.485508
# 3       PTS  20.198311
# 4       TRB   9.742589
# 5       AST   9.188839
# 6       STL   7.376752
# 7       BLK   3.924265
# 8       TOV  12.668902

# %% [markdown]
# Based on this data, punting blocks seems like the best option... the histogram shows that the vast majority of players average less than 0.5 blocks per game - this means there are few elite shot blockers and they're likely to get draftd early on. Furthermore, blocks are least co-linear with most other categories and therefore can be punted with little consequence. Total rebounds does take a hit, however, there are quite a few bigs that are weak shot-blockers.
